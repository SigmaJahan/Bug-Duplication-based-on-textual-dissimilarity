# %%
#importing necessary libraries 
import pandas as pd
import nltk
import gensim
from gensim.utils import simple_preprocess
from nltk.corpus import stopwords
from nltk import word_tokenize
from nltk.stem import WordNetLemmatizer, SnowballStemmer
from nltk.stem.porter import *
from gensim.parsing.preprocessing import STOPWORDS
import numpy as np
import pickle
nltk.download('stopwords')
nltk.download('wordnet')
from typing import List, Dict, Tuple, Set
import itertools
import warnings
warnings.filterwarnings("ignore", category=DeprecationWarning)
import pickle
import requests
import json
import urllib.request
import time
from bs4 import BeautifulSoup
from sklearn.feature_extraction.text import TfidfVectorizer
from nltk.stem import PorterStemmer
import re
from sklearn.metrics.pairwise import cosine_similarity
import statistics
from datetime import datetime
from scipy.stats import skew
from sklearn.datasets import make_circles
from sklearn.metrics import accuracy_score
from sklearn.metrics import precision_score
from sklearn.metrics import recall_score
from sklearn.metrics import f1_score
from sklearn.metrics import cohen_kappa_score
from sklearn.metrics import roc_auc_score
from sklearn.metrics import confusion_matrix
from keras.models import Sequential
from keras.layers import Dense
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data]   Unzipping corpora/wordnet.zip.

# %%
#mounting the google drive
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# ## Reading dataset

# %%
#importing the CSV file of the dataset from google drive into a dataframe
train_eclipse_df=pd.read_csv('drive/MyDrive/Project 6308 + ICSME/Siamese/Mobile_siamese_train_preprocessed.csv')
train_eclipse_df
# Out:
#       Unnamed: 0                                       description1  \
# 0              0    this way we can hold the placeholder color a...
# 1              1    having two build targets for this takes doub...
# 2              2    we are adding a feature now to focus klar to...
# 3              3    user agent  mozilla       gecko   firefox   ...
# 4              4    created attachment     png  build    device ...
# ...          ...                                                ...
# 3818        4221    starting on   x highlights will be removed a...
# 3819        4223    user agent  mozilla       gecko   firefox   ...
# 3820        4224    the mobile performance team thinks having ma...
# 3821        4225    final copy here ready for localization  goal...
# 3822        4226    build       device  iphone   plus ios       ...
#
#                                            description2  is_similar
# 0       the quick work around in bug   didn t quite ...           0
# 1       filed by  btara  at  mozilla com     job id ...           0
# 2       now that the user can browse   documents in ...           0
# 3       user agent  mozilla       gecko   firefox   ...           1
# 4       right now we have to use intents  which is c...           0
# ...                                                 ...         ...
# 3818    there are few additional events that we want...           0
# 3819    this currently fails due to some raciness wi...           0
# 3820    created attachment   screen shot       at   ...           0
# 3821    from github    to bugzilla issues       this...           0
# 3822    created attachment     startup time mov  see...           0
#
# [3823 rows x 4 columns]

# %%
#importing the CSV file of the dataset from google drive into a dataframe
test_eclipse_df=pd.read_csv('drive/MyDrive/Project 6308 + ICSME/Siamese/Mobile_siamese_test_preprocessed.csv')
test_eclipse_df
# Out:
#      Unnamed: 0                                       description1  \
# 0             0    to integrate the functionality of taking scr...
# 1             1    created attachment     png  master build    ...
# 2             2    sebastian reports that  input type  file   d...
# 3             3    visit   and the page doesn t load unless you...
# 4             4     geckoprocessmanager  needs to support multi...
# ..          ...                                                ...
# 954        1058    user agent  mozilla       applewebkit       ...
# 955        1059    i just updated to sierra   and updated xcode...
# 956        1060    created attachment   broken sites after fix ...
# 957        1062    there is a new option when long pressing on ...
# 958        1063    filed by  aiakab  at  mozilla com     job id...
#
#                                           description2  is_similar
# 0      created attachment   screen shot       at   ...           0
# 1      filed by  cbrindusan  at  mozilla com     jo...           0
# 2      robin mentioned that  i want to edit a url a...           0
# 3      bug   ran geckoview mochitest on  opt builds...           0
# 4      created attachment      user agent  mozilla ...           0
# ..                                                 ...         ...
# 954    created attachment      user agent  mozilla ...           0
# 955       central as beta simulation      how to ru...           0
# 956    as part of the fission work we need to migra...           0
# 957    we enabled browser tabs remote autostart in ...           0
# 958    created attachment   screenshot of the outpu...           0
#
# [959 rows x 4 columns]

# %%
#Merge train & test
frames = [train_eclipse_df, test_eclipse_df]
result = pd.concat(frames)
result = result.sample(frac=1, random_state=1).reset_index(drop=True)
result1 = result.copy()
dup_df= result.copy()
dup_df
# Out:
#       Unnamed: 0                                       description1  \
# 0           1375    the following deep links are no longer worki...
# 1           3716    created attachment   screen shot       at   ...
# 2           2919    repeat performance of bug    this time for g...
# 3           3482    there have been a number of bugs  false alar...
# 4            784    created attachment   poc html  user agent  m...
# ...          ...                                                ...
# 4777        3207    str     visit a page you want to read  like ...
# 4778        3067    initial module settings are no longer propag...
# 4779        1002    right now if you click a link with target  b...
# 4780         182    geckoview example crashes on the youtube com...
# 4781         254    the tps addon was updated to a web extension...
#
#                                            description2  is_similar
# 0         filed by    malexandru  at  mozilla com   ...           0
# 1       this is due to geckoviewhistory unconditiona...           0
# 2       simion   if you can help with qa ing this is...           0
# 3       there have been a number of bugs  false alar...           1
# 4           this bug was initially created as a clon...           0
# ...                                                 ...         ...
# 4777    build      device  ipad air   ios         pr...           0
# 4778    created attachment   screen shot       at   ...           0
# 4779    currently when building geckoview on macos  ...           0
# 4780    if you scroll down slowly on a webpage the t...           0
# 4781    we have implemented telemetry dashboards tha...           0
#
# [4782 rows x 4 columns]

# %%
FEATURES = ['description1', 'description2']
print('Description of length of the feature columns')
dup_df[FEATURES].apply(lambda col: col.str.len().describe())
# Out:
# Description of length of the feature columns
#        description1  description2
# count   4782.000000   4782.000000
# mean    1045.613760    994.800502
# std     2925.653641   2696.171659
# min       50.000000     50.000000
# 25%      176.000000    176.000000
# 50%      324.000000    320.000000
# 75%      583.000000    578.000000
# max    40577.000000  40577.000000

# %% [markdown]
# ## Train, Validation, Test Split

# %%
from sklearn.model_selection import train_test_split
import random
import sklearn

# %%
train_val_df = train_eclipse_df.copy()
train_val_df
# Out:
#       Unnamed: 0                                       description1  \
# 0              0    this way we can hold the placeholder color a...
# 1              1    having two build targets for this takes doub...
# 2              2    we are adding a feature now to focus klar to...
# 3              3    user agent  mozilla       gecko   firefox   ...
# 4              4    created attachment     png  build    device ...
# ...          ...                                                ...
# 3818        4221    starting on   x highlights will be removed a...
# 3819        4223    user agent  mozilla       gecko   firefox   ...
# 3820        4224    the mobile performance team thinks having ma...
# 3821        4225    final copy here ready for localization  goal...
# 3822        4226    build       device  iphone   plus ios       ...
#
#                                            description2  is_similar
# 0       the quick work around in bug   didn t quite ...           0
# 1       filed by  btara  at  mozilla com     job id ...           0
# 2       now that the user can browse   documents in ...           0
# 3       user agent  mozilla       gecko   firefox   ...           1
# 4       right now we have to use intents  which is c...           0
# ...                                                 ...         ...
# 3818    there are few additional events that we want...           0
# 3819    this currently fails due to some raciness wi...           0
# 3820    created attachment   screen shot       at   ...           0
# 3821    from github    to bugzilla issues       this...           0
# 3822    created attachment     startup time mov  see...           0
#
# [3823 rows x 4 columns]

# %%
 test_df = test_eclipse_df.copy()
 test_df
# Out:
#      Unnamed: 0                                       description1  \
# 0             0    to integrate the functionality of taking scr...
# 1             1    created attachment     png  master build    ...
# 2             2    sebastian reports that  input type  file   d...
# 3             3    visit   and the page doesn t load unless you...
# 4             4     geckoprocessmanager  needs to support multi...
# ..          ...                                                ...
# 954        1058    user agent  mozilla       applewebkit       ...
# 955        1059    i just updated to sierra   and updated xcode...
# 956        1060    created attachment   broken sites after fix ...
# 957        1062    there is a new option when long pressing on ...
# 958        1063    filed by  aiakab  at  mozilla com     job id...
#
#                                           description2  is_similar
# 0      created attachment   screen shot       at   ...           0
# 1      filed by  cbrindusan  at  mozilla com     jo...           0
# 2      robin mentioned that  i want to edit a url a...           0
# 3      bug   ran geckoview mochitest on  opt builds...           0
# 4      created attachment      user agent  mozilla ...           0
# ..                                                 ...         ...
# 954    created attachment      user agent  mozilla ...           0
# 955       central as beta simulation      how to ru...           0
# 956    as part of the fission work we need to migra...           0
# 957    we enabled browser tabs remote autostart in ...           0
# 958    created attachment   screenshot of the outpu...           0
#
# [959 rows x 4 columns]

# %%
train_df, val_df = train_test_split(
  train_val_df,
  test_size=0.2,
  stratify=train_val_df.is_similar,
  random_state=13,
)

# %%
train_df
# Out:
#       Unnamed: 0                                       description1  \
# 154          166    scenario  i have an app with multiple tabs a...
# 90            99    we see valid urls being rejected due to  uns...
# 2460        2727    str     load   signed badssl com in fenix   ...
# 714          787    this should use production autopush servers ...
# 1638        1818    following investigation of bug    we ved fou...
# ...          ...                                                ...
# 2652        2942    older versions of the sentry dependency pull...
# 2265        2514    this bug is for crash report bp             ...
# 2590        2871    the highlights section does not seem to upda...
# 3104        3445    when syncing open tabs from an ios device to...
# 3198        3550    created attachment     png  on beta      it ...
#
#                                            description2  is_similar
# 154     build        device  ipad air   ios         ...           0
# 90      for some reason i thought we already did tha...           0
# 2460    str     load   signed badssl com in fenix   ...           1
# 714     created attachment   hardcore wrap png  see ...           0
# 1638    filed by  cbrindusan  at  mozilla com     jo...           0
# ...                                                 ...         ...
# 2652    upgrade to       is happening in bug     ver...           0
# 2265    there are two tests suites that only apply f...           0
# 2590    filed by  nbeleuzu  at  mozilla com     job ...           0
# 3104    master   iphone   plus       sign into sync ...           0
# 3198    user agent  mozilla       applewebkit       ...           0
#
# [3058 rows x 4 columns]

# %%
len(val_df[val_df.is_similar.astype('bool')]) / len(val_df)
# Out:
# 0.0718954248366013

# %%
from collections import Counter
from sklearn.datasets import make_classification
from imblearn.over_sampling import RandomOverSampler

# %%
label= train_df.is_similar
type(label)
# Out:
# pandas.core.series.Series

# %%
type(train_df)
# Out:
# pandas.core.frame.DataFrame

# %%
sm = RandomOverSampler(random_state=42)
X_res, y_res = sm.fit_resample(X=train_df[['description1', 'description2']], y=train_df.is_similar)

# %%
train_df = X_res.copy()
train_df['is_similar'] = y_res
train_df = train_df.sample(frac=1)

# %%
train_df
# Out:
#                                            description1  \
# 1143    please include ymail  in the settings page u...
# 4510    this implements the  cookiestoreid  paramete...
# 4409    with the addition of  open in firefox   ux h...
# 3820    from bug   comment   and          hwinnemoe ...
# 907     created attachment     png  user agent  mozi...
# ...                                                 ...
# 951     user agent  mozilla       gecko   firefox   ...
# 5028      filed by    rgurzau  at  mozilla com   par...
# 2723    update snapshothelper swift to       this is...
# 193     mocks are here     screens   work will be sp...
# 2569    build    device  iphone   ios       steps to...
#
#                                            description2  is_similar
# 1143    the favicon url matching logic should be pul...           0
# 4510    this implements the  cookiestoreid  paramete...           1
# 4409    with the addition of  open in firefox   ux h...           1
# 3820    from bug   comment   and          hwinnemoe ...           1
# 907     this test seems to be failing due to a timin...           0
# ...                                                 ...         ...
# 951     lets disable these tests for iphone schema u...           0
# 5028      filed by    rgurzau  at  mozilla com   par...           1
# 2723    user agent  mozilla       gecko   firefox   ...           0
# 193     repro on latest master    only on ipad   ste...           0
# 2569    right now focus calls savestate  from a back...           0
#
# [5680 rows x 3 columns]

# %%
len(train_df[train_df.is_similar.astype('bool')]) / len(train_df)
# Out:
# 0.5

# %%
print(f'Train Val Test Size: {len(train_df):,} {len(val_df):,} {len(test_df):,}')
# Out:
# Train Val Test Size: 5,680 765 959

# %% [markdown]
# ## Download & Prepare Embedding

# %%
import os
os.environ['CUDA_VISIBLE_DEVICES'] = '-1'

import tensorflow as tf
import tensorflow.keras.utils as kutils
from keras.layers.preprocessing.text_vectorization import TextVectorization

# %% [markdown]
# ## create vocabulary index

# %%
from typing import List

# %%
MAX_TOKENS = 20000
MAX_TITLE_LENGTH = 21
MAX_DESCRIPTION_LENGTH = 1000
EMBEDDING_DIM = 100

# %%
def build_vocab(sentences: List[str], sequence_length: int):
  vectorizer = TextVectorization(
    max_tokens=MAX_TOKENS - 2,
    output_sequence_length=sequence_length,
  )
  vectorizer.adapt(sentences)
  vocab = vectorizer.get_vocabulary()
  word_index = dict(zip(vocab, range(len(vocab))))

  return vectorizer, word_index

# %%
descr_vectorizer, descr_word_index = build_vocab(
  [dup_df.description1, dup_df.description2],
  MAX_DESCRIPTION_LENGTH,
)

print(
  'Most frequent description words:',
  list(itertools.islice(descr_word_index.keys(), 5)),
)
# Out:
# Most frequent description words: ['', '[UNK]', 'task', 'info', 'mozilla']

# %%
len(descr_word_index)
# Out:
# 12409

# %% [markdown]
# ## Prepare Training Data

# %%
def generate_batches(
  split_df: pd.DataFrame,
  batch_size=1024,
):
  steps_per_epoch = len(split_df) // batch_size
  while True:
    for i in range(steps_per_epoch):
      offset = i * batch_size
      till = offset + batch_size
      feature_batches = []
      for feature in FEATURES:
        vectorizer = descr_vectorizer
        feature_batch = vectorizer(
          split_df[feature][offset: till].to_numpy().reshape((-1, 1))
        ).numpy()
        feature_batches.append(feature_batch)


      target_batch = split_df.is_similar[offset: till].to_numpy()
      yield (
        feature_batches,
        target_batch,
      )

# %% [markdown]
# ## Create Models

# %%
from tensorflow.keras import layers
from tensorflow.keras import models
from tensorflow.keras import callbacks
from keras.initializers.initializers_v2 import Constant

# %%
DescrEmbeddingLayer = layers.Embedding(
  input_dim=MAX_TOKENS,
  output_dim=EMBEDDING_DIM,
  name='DescrEmbeddingLayer',
)

def make_descr_layer(num, kernel_size=3, pool_size=2, strides=None):
  DescrConv1dLayer = layers.Conv1D(
    filters=32,
    kernel_size=kernel_size,
    activation='relu',
    name=f'DescrConv1dLayer{num}',
  )
  DescrMaxPool1dLayer = layers.MaxPool1D(
    pool_size=pool_size,
    strides=strides,
    name=f'DescrMaxPool1dLayer{num}',
  )
  return DescrConv1dLayer, DescrMaxPool1dLayer

DescrConv1dLayer1, DescrMaxPool1dLayer1 = make_descr_layer(1, pool_size=4)
DescrConv1dLayer2, DescrMaxPool1dLayer2 = make_descr_layer(2)

# %%
def create_siamese_component(num: int):
  class SiameseComponent:
    def __init__(self, title: layers.Input, description: layers.Input, output: layers.Concatenate):
      self.title = title
      self.description = description
      self.output = output

  title_input = layers.Input(shape=(None,), dtype='int32', name=f'title{num}_input')

  descr_input = layers.Input(shape=(None,), name=f'descr{num}_input')
  descr_embedding_layer = DescrEmbeddingLayer(descr_input)
  descr_conv1d1 = DescrConv1dLayer1(descr_embedding_layer)
  descr_max_pool1d1 = DescrMaxPool1dLayer1(descr_conv1d1)
  descr_conv1d2 = DescrConv1dLayer2(descr_max_pool1d1)
  descr_max_pool1d2 = DescrMaxPool1dLayer2(descr_conv1d2)
  # descr_conv1d3 = DescrConv1dLayer3(descr_max_pool1d2)
  # descr_max_pool1d3 = DescrMaxPool1dLayer3(descr_conv1d3)
  descr_flat_Layer = layers.Flatten(name=f'FlatDescr{num}')(descr_max_pool1d2)
  
  concat = layers.Concatenate(axis=1, name=f'Concat{num}')([descr_flat_Layer])
  return SiameseComponent(title_input, descr_input, concat)


component1 = create_siamese_component(1)
component2 = create_siamese_component(2)

dot_product_layer = layers.Dot(
  axes=1,
  name='dot_product_layer'
)([component1.output, component2.output])
output = layers.Dense(
  1, activation='sigmoid', name='output',
)(dot_product_layer)
siamese_model = models.Model(
  inputs=[component1.description, component2.description],
  outputs=output,
  name='siamese_model'
)

kutils.plot_model(siamese_model)

# %% [markdown]
# ## Train

# %%
BATCH_SIZE = 144

siamese_model.compile(
  loss='binary_crossentropy',
  optimizer='adam',
  metrics=['acc'],
)
callback = callbacks.ModelCheckpoint(
    filepath=f'../../drive/MyDrive/Project 6308 + ICSME/Siamese'
             '.epoch-{epoch:02d}-loss-{val_loss:.3f}.hdf5',
    monitor='val_loss',
    verbose=0,
    save_best_only=True,
    mode='min',
)

# %%
history = siamese_model.fit(
  generate_batches(train_df, BATCH_SIZE),
  steps_per_epoch=len(train_df) // BATCH_SIZE,
  epochs=30,
  validation_data=generate_batches(val_df, BATCH_SIZE),
  validation_steps=len(val_df) // BATCH_SIZE,
  verbose=1,
  # callbacks= [callback]
)
# Out:
# Epoch 1/30
# 39/39 [==============================] - 35s 848ms/step - loss: 0.6920 - acc: 0.5053 - val_loss: 0.6203 - val_acc: 0.9278
# Epoch 2/30
# 39/39 [==============================] - 31s 807ms/step - loss: 0.5980 - acc: 0.5344 - val_loss: 0.4083 - val_acc: 0.9375
# Epoch 3/30
# 39/39 [==============================] - 31s 807ms/step - loss: 0.4122 - acc: 0.8422 - val_loss: 0.8041 - val_acc: 0.9167
# Epoch 4/30
# 39/39 [==============================] - 32s 813ms/step - loss: 0.3553 - acc: 0.9614 - val_loss: 1.2364 - val_acc: 0.8931
# Epoch 5/30
# 39/39 [==============================] - 32s 811ms/step - loss: 0.3370 - acc: 0.9642 - val_loss: 1.5413 - val_acc: 0.8889
# Epoch 6/30
# 39/39 [==============================] - 32s 815ms/step - loss: 0.3250 - acc: 0.9658 - val_loss: 1.7963 - val_acc: 0.8806
# Epoch 7/30
# 39/39 [==============================] - 32s 810ms/step - loss: 0.3146 - acc: 0.9685 - val_loss: 1.9325 - val_acc: 0.8764
# Epoch 8/30
# 39/39 [==============================] - 31s 807ms/step - loss: 0.3056 - acc: 0.9676 - val_loss: 1.9606 - val_acc: 0.8653
# Epoch 9/30
# 39/39 [==============================] - 31s 806ms/step - loss: 0.2980 - acc: 0.9663 - val_loss: 2.0323 - val_acc: 0.8597
# Epoch 10/30
# 39/39 [==============================] - 32s 811ms/step - loss: 0.2895 - acc: 0.9674 - val_loss: 2.1731 - val_acc: 0.8597
# Epoch 11/30
# 39/39 [==============================] - 32s 811ms/step - loss: 0.2831 - acc: 0.9674 - val_loss: 2.2751 - val_acc: 0.8583
# Epoch 12/30
# 39/39 [==============================] - 32s 812ms/step - loss: 0.2747 - acc: 0.9710 - val_loss: 2.7195 - val_acc: 0.8653
# Epoch 13/30
# 39/39 [==============================] - 32s 810ms/step - loss: 0.2683 - acc: 0.9708 - val_loss: 2.9173 - val_acc: 0.8667
# Epoch 14/30
# 39/39 [==============================] - 32s 815ms/step - loss: 0.2601 - acc: 0.9733 - val_loss: 3.2916 - val_acc: 0.8708
# Epoch 15/30
# 39/39 [==============================] - 32s 812ms/step - loss: 0.2535 - acc: 0.9729 - val_loss: 3.7523 - val_acc: 0.8681
# Epoch 16/30
# 39/39 [==============================] - 32s 814ms/step - loss: 0.2484 - acc: 0.9728 - val_loss: 3.9699 - val_acc: 0.8653
# Epoch 17/30
# 39/39 [==============================] - 32s 813ms/step - loss: 0.2419 - acc: 0.9738 - val_loss: 4.4253 - val_acc: 0.8708
# Epoch 18/30
# 39/39 [==============================] - 32s 814ms/step - loss: 0.2371 - acc: 0.9731 - val_loss: 4.3278 - val_acc: 0.8653
# Epoch 19/30
# 39/39 [==============================] - 32s 814ms/step - loss: 0.2307 - acc: 0.9758 - val_loss: 4.7033 - val_acc: 0.8667
# Epoch 20/30
# 39/39 [==============================] - 32s 811ms/step - loss: 0.2271 - acc: 0.9735 - val_loss: 4.6787 - val_acc: 0.8611
# Epoch 21/30
# 39/39 [==============================] - 32s 813ms/step - loss: 0.2212 - acc: 0.9754 - val_loss: 5.0746 - val_acc: 0.8681
# Epoch 22/30
# 39/39 [==============================] - 32s 813ms/step - loss: 0.2155 - acc: 0.9767 - val_loss: 5.6631 - val_acc: 0.8611
# Epoch 23/30
# 39/39 [==============================] - 32s 815ms/step - loss: 0.2120 - acc: 0.9772 - val_loss: 5.8312 - val_acc: 0.8653
# Epoch 24/30
# 39/39 [==============================] - 32s 816ms/step - loss: 0.2054 - acc: 0.9783 - val_loss: 6.1771 - val_acc: 0.8653
# Epoch 25/30
# 39/39 [==============================] - 32s 819ms/step - loss: 0.2012 - acc: 0.9781 - val_loss: 6.5125 - val_acc: 0.8639
# Epoch 26/30
# 39/39 [==============================] - 32s 818ms/step - loss: 0.1968 - acc: 0.9795 - val_loss: 6.4259 - val_acc: 0.8597
# Epoch 27/30
# 39/39 [==============================] - 32s 813ms/step - loss: 0.1917 - acc: 0.9802 - val_loss: 7.2819 - val_acc: 0.8667
# Epoch 28/30
# 39/39 [==============================] - 32s 814ms/step - loss: 0.1873 - acc: 0.9801 - val_loss: 7.8710 - val_acc: 0.8694
# Epoch 29/30
# 39/39 [==============================] - 32s 813ms/step - loss: 0.1833 - acc: 0.9809 - val_loss: 7.9701 - val_acc: 0.8653
# Epoch 30/30
# 39/39 [==============================] - 32s 812ms/step - loss: 0.1809 - acc: 0.9804 - val_loss: 8.1290 - val_acc: 0.8639

# %%
siamese_model.save('something.hd5')
# Out:
# INFO:tensorflow:Assets written to: something.hd5/assets

# %%
something.hd5
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-36-4d443ea7b347> in <module>()
# ----> 1 something.hd5
#
# NameError: name 'something' is not defined

# %%
ax = pd.DataFrame(history.history).plot()

# %%
from keras.utils.vis_utils import plot_model
from matplotlib import pyplot
import matplotlib.pyplot as plt
plot_model(siamese_model, to_file='model_plot.png', show_shapes=True, show_layer_names=True)
# plot the loss
plt.plot(history.history['loss'], label='train loss')
plt.plot(history.history['val_loss'], label='val loss')
plt.legend()
plt.show()
plt.savefig('LossVal_loss')

# %%
# plot the accuracy
from sklearn.metrics import accuracy_score
plt.plot(history.history['acc'], label='train acc')
plt.plot(history.history['val_acc'], label='val acc')
plt.legend()
plt.show()
plt.savefig('AccVal_acc')

# %% [markdown]
# ## Evaluate on test data

# %%
# from tensorflow.keras.models import load_model

# siamese_model = load_model('../../models/siamese-openOffice.epoch-30-loss-0.457.hdf5')

# %%
siamese_model.evaluate(
  generate_batches(test_df, BATCH_SIZE),
  steps=len(test_df) // BATCH_SIZE,
)
# Out:
# 6/6 [==============================] - 1s 186ms/step - loss: 0.6959 - acc: 0.9132
# [0.6958866119384766, 0.9131944179534912]

# %%
len(test_df)
# Out:
# 959

# %%
BATCH_SIZE = len(test_df)
num_batched_instances = len(test_df) - (len(test_df) % BATCH_SIZE)
pred_y = siamese_model.predict(
  generate_batches(test_df, BATCH_SIZE),
  steps=len(test_df) // BATCH_SIZE,
  verbose=1,
)
# Out:
# 1/1 [==============================] - 2s 2s/step

# %%
from sklearn.metrics import classification_report
print(classification_report(
  test_df.is_similar[:num_batched_instances],
  pred_y > .5,
))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.98      0.92      0.95       906
#            1       0.36      0.74      0.49        53
#
#     accuracy                           0.91       959
#    macro avg       0.67      0.83      0.72       959
# weighted avg       0.95      0.91      0.93       959

# %%
import sklearn
from sklearn.metrics import confusion_matrix
from sklearn.metrics import confusion_matrix,accuracy_score,classification_report,roc_auc_score
import numpy as np; np.random.seed(0)
import seaborn as sns; sns.set_theme()
from sklearn.metrics import accuracy_score
import sklearn.metrics as metrics

# %%
from sklearn.metrics import roc_curve

value_names = ['TPR', 'FPR', 'Threshold']
roc = dict(zip(value_names, roc_curve(
  test_df.is_similar[:num_batched_instances],
  pred_y,
)))
pd.DataFrame(roc)
# Out:
#          TPR       FPR     Threshold
# 0   0.000000  0.000000  1.749272e+00
# 1   0.033113  0.377358  7.492718e-01
# 2   0.035320  0.377358  7.492070e-01
# 3   0.035320  0.415094  7.490417e-01
# 4   0.037528  0.415094  7.488719e-01
# 5   0.037528  0.433962  7.488030e-01
# 6   0.040839  0.433962  7.479079e-01
# 7   0.040839  0.452830  7.476323e-01
# 8   0.045254  0.452830  7.467082e-01
# 9   0.045254  0.471698  7.465678e-01
# 10  0.048565  0.471698  7.456243e-01
# 11  0.048565  0.490566  7.455493e-01
# 12  0.050773  0.490566  7.427952e-01
# 13  0.050773  0.547170  7.341442e-01
# 14  0.052980  0.547170  7.267155e-01
# 15  0.052980  0.603774  7.201133e-01
# 16  0.056291  0.603774  6.868201e-01
# 17  0.056291  0.641509  6.817330e-01
# 18  0.057395  0.641509  6.757068e-01
# 19  0.057395  0.660377  6.662883e-01
# 20  0.062914  0.660377  6.273400e-01
# 21  0.062914  0.679245  6.270496e-01
# 22  0.069536  0.679245  6.035824e-01
# 23  0.069536  0.698113  5.977829e-01
# 24  0.071744  0.698113  5.712191e-01
# 25  0.071744  0.716981  5.632413e-01
# 26  0.073951  0.716981  5.527915e-01
# 27  0.073951  0.735849  5.488623e-01
# 28  0.080574  0.735849  4.699519e-01
# 29  0.080574  0.754717  4.426817e-01
# 30  0.096026  0.754717  3.360202e-01
# 31  0.096026  0.773585  3.326504e-01
# 32  0.108168  0.773585  1.508200e-01
# 33  0.108168  0.811321  1.486249e-01
# 34  0.216336  0.811321  3.157854e-04
# 35  0.216336  0.830189  3.055334e-04
# 36  0.221854  0.830189  1.492798e-04
# 37  0.221854  0.849057  1.482666e-04
# 38  0.333333  0.849057  2.429803e-07
# 39  0.333333  0.867925  1.900587e-07
# 40  0.459161  0.867925  3.720513e-12
# 41  0.459161  0.886792  3.600663e-12
# 42  0.473510  0.886792  1.224618e-12
# 43  0.473510  0.905660  1.045254e-12
# 44  0.524283  0.905660  7.955837e-15
# 45  0.524283  0.924528  6.941640e-15
# 46  0.540839  0.924528  1.693237e-15
# 47  0.540839  0.943396  1.594427e-15
# 48  0.799117  0.943396  7.539567e-37
# 49  0.799117  0.962264  6.115378e-37
# 50  0.807947  0.962264  1.700038e-38
# 51  1.000000  1.000000  0.000000e+00

# %%
from sklearn.metrics import roc_auc_score

auroc = roc_auc_score(
  test_df.is_similar[:num_batched_instances],
  pred_y,
)

print('AUROC score:', auroc)
# Out:
# AUROC score: 0.865987754592028

# %%
print('For probability:')
print(f'Mean: {pred_y.mean()}, STD: {pred_y.std()}')
print('For categorical:')
print(f'Mean: {(pred_y > .5).mean()}, STD: {(pred_y > .5).std()}')
# Out:
# For probability:
# Mean: 0.09385187923908234, STD: 0.23054569959640503
# For categorical:
# Mean: 0.11157455683003129, STD: 0.3148423019516491

# %% [markdown]
# ## Evaluate on textually similar data

# %%
#importing the CSV file of the dataset from google drive into a dataframe
sim_df=pd.read_csv('drive/MyDrive/Project 6308 + ICSME/Siamese/Mobile_siamese_textually_similar_test_duplicates_preprocessed.csv')
sim_df
# Out:
#     Unnamed: 0                                       description1  \
# 0            0    created attachment     png  user agent  mozi...
# 1            1    seen on fenix     mobile fenix issues     a ...
# 2            2     java lang exception  data is null       at ...
# 3            3    created attachment   video demonstrating the...
# 4            4      filed by    apavel  at  mozilla com   pars...
# ..         ...                                                ...
# 67          94      filed by    dvarga  at  mozilla com   pars...
# 68          95    build  master   device  ipad air   ios      ...
# 69          97    crash report    stats mozilla org report ind...
# 70          98    this bug continues a conversation from the o...
# 71          99      filed by    abutkovits  at  mozilla com   ...
#
#                                          description2  is_similar
# 0       filed by    nerli  at  mozilla com   parse...           0
# 1     user agent  mozilla       gecko   firefox   ...           0
# 2     str reported on fenix issue tracker    mobil...           1
# 3       filed by    malexandru  at  mozilla com   ...           0
# 4       filed by    malexandru  at  mozilla com   ...           1
# ..                                                ...         ...
# 67      filed by    nbeleuzu  at  mozilla com   pa...           0
# 68    build  master   device  ipad air   ios      ...           0
# 69      filed by    aklotz  at  mozilla com   pars...           0
# 70    as part of the webextension support in bug  ...           1
# 71    seen on fenix     mobile fenix issues     a ...           0
#
# [72 rows x 4 columns]

# %%
len(sim_df)
# Out:
# 72

# %%
BATCH_SIZE = len(sim_df)
num_batched_instances = len(sim_df) - (len(sim_df) % BATCH_SIZE)
pred_y_sim = siamese_model.predict(
  generate_batches(sim_df, BATCH_SIZE),
  steps=len(sim_df) // BATCH_SIZE,
  verbose=1,
)
# Out:
# 1/1 [==============================] - 0s 133ms/step

# %%
siamese_model.evaluate(
  generate_batches(sim_df, BATCH_SIZE),
  steps=len(sim_df) // BATCH_SIZE,
)
# Out:
# 1/1 [==============================] - 0s 140ms/step - loss: 9.0258 - acc: 0.6944
# [9.025760650634766, 0.6944444179534912]

# %%
from sklearn.metrics import classification_report

print(classification_report(
  sim_df.is_similar[:num_batched_instances],
  pred_y_sim > .5,
))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.77      0.80      0.79        51
#            1       0.47      0.43      0.45        21
#
#     accuracy                           0.69        72
#    macro avg       0.62      0.62      0.62        72
# weighted avg       0.69      0.69      0.69        72

# %%
from sklearn.metrics import roc_curve

value_names = ['TPR', 'FPR', 'Threshold']
roc = dict(zip(value_names, roc_curve(
  sim_df.is_similar[:num_batched_instances],
  pred_y_sim,
)))
pd.DataFrame(roc)
# Out:
#          TPR       FPR     Threshold
# 0   0.000000  0.000000  1.749272e+00
# 1   0.039216  0.190476  7.492718e-01
# 2   0.039216  0.333333  7.455493e-01
# 3   0.058824  0.333333  7.435172e-01
# 4   0.058824  0.428571  7.381551e-01
# 5   0.215686  0.428571  3.370835e-01
# 6   0.215686  0.523810  1.486249e-01
# 7   0.372549  0.523810  3.755689e-04
# 8   0.372549  0.571429  3.709793e-04
# 9   0.470588  0.571429  3.267450e-07
# 10  0.470588  0.619048  2.777358e-07
# 11  0.509804  0.619048  1.977889e-07
# 12  0.509804  0.666667  1.900587e-07
# 13  0.666667  0.666667  1.680677e-13
# 14  0.666667  0.761905  1.594427e-15
# 15  0.705882  0.761905  1.123424e-18
# 16  0.705882  0.809524  9.111061e-20
# 17  0.725490  0.809524  2.914669e-21
# 18  0.725490  0.857143  1.860336e-24
# 19  0.745098  0.857143  2.186890e-26
# 20  0.745098  0.904762  3.469148e-28
# 21  1.000000  1.000000  0.000000e+00

# %%
from sklearn.metrics import roc_auc_score

auroc = roc_auc_score(
  sim_df.is_similar[:num_batched_instances],
  pred_y_sim,
)

print('AUROC score:', auroc)
# Out:
# AUROC score: 0.649859943977591

# %%
print('For probability:')
print(f'Mean: {pred_y_sim.mean()}, STD: {pred_y_sim.std()}')
print('For categorical:')
print(f'Mean: {(pred_y_sim > .5).mean()}, STD: {(pred_y_sim > .5).std()}')
# Out:
# For probability:
# Mean: 0.20402495563030243, STD: 0.31636977195739746
# For categorical:
# Mean: 0.2638888888888889, STD: 0.4407397681284008

# %% [markdown]
# ## Evaluate on textually dissimilar data

# %%
#importing the CSV file of the dataset from google drive into a dataframe
dissim_df=pd.read_csv('drive/MyDrive/Project 6308 + ICSME/Siamese/Mobile_siamese_textually_dissimilar_test_duplicates_preprocessed.csv')
dissim_df
# Out:
#     Unnamed: 0                                       description1  \
# 0            0    user agent  mozilla       applewebkit       ...
# 1            2    we should investigate what s the story for p...
# 2            3    str    start geckoview example   from settin...
# 3            4        this bug was initially created as a clon...
# 4            5    see this comment for details    mobile firef...
# ..         ...                                                ...
# 71          95    sometimes when typing in a textbox on nightl...
# 72          96    the brief crash report   thread   name  thre...
# 73          99    lets support the new password autofill spec ...
# 74         100    we had this crash in fxr    stats mozilla or...
# 75         101    adding this api to gve will help resolve bug...
#
#                                          description2  is_similar
# 0     created attachment   screen shot       at   ...           0
# 1     currently  the gv autocomplete api only supp...           1
# 2     it isn t clear how this currently works     ...           0
# 3     user agent  mozilla       applewebkit       ...           1
# 4     url is   form validation      input id  choo...           0
# ..                                                ...         ...
# 71    provide a user to have anywhere from       t...           0
# 72    this crash is happening in firefox for ios  ...           1
# 73    currently geckoview s progressdelegate does ...           0
# 74     geckoresult allow  is sometimes created on ...           1
# 75    this was a feature request from the october ...           1
#
# [76 rows x 4 columns]

# %%
BATCH_SIZE = len(dissim_df)
num_batched_instances = len(dissim_df) - (len(dissim_df) % BATCH_SIZE)
pred_y_dis = siamese_model.predict(
  generate_batches(dissim_df, BATCH_SIZE),
  steps=len(dissim_df) // BATCH_SIZE,
  verbose=1,
)
# Out:
# 1/1 [==============================] - 0s 132ms/step

# %%
siamese_model.evaluate(
  generate_batches(dissim_df, BATCH_SIZE),
  steps=len(dissim_df) // BATCH_SIZE,
)
# Out:
# 1/1 [==============================] - 0s 119ms/step - loss: 9.5833 - acc: 0.6974
# [9.583279609680176, 0.6973684430122375]

# %%
from sklearn.metrics import classification_report

print(classification_report(
  dissim_df.is_similar[:num_batched_instances],
  pred_y_dis > .5,
))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.66      0.93      0.77        42
#            1       0.82      0.41      0.55        34
#
#     accuracy                           0.70        76
#    macro avg       0.74      0.67      0.66        76
# weighted avg       0.73      0.70      0.67        76

# %%
from sklearn.metrics import roc_curve

value_names = ['TPR', 'FPR', 'Threshold']
roc = dict(zip(value_names, roc_curve(
  dissim_df.is_similar[:num_batched_instances],
  pred_y_dis,
)))
pd.DataFrame(roc)
# Out:
#          TPR       FPR     Threshold
# 0   0.000000  0.000000  1.749272e+00
# 1   0.000000  0.264706  7.492718e-01
# 2   0.000000  0.323529  7.409154e-01
# 3   0.023810  0.323529  7.323660e-01
# 4   0.023810  0.352941  7.304488e-01
# 5   0.047619  0.352941  7.172246e-01
# 6   0.047619  0.382353  7.113299e-01
# 7   0.071429  0.382353  6.100274e-01
# 8   0.071429  0.411765  5.873207e-01
# 9   0.095238  0.411765  3.892545e-01
# 10  0.095238  0.441176  3.656239e-01
# 11  0.357143  0.441176  3.910261e-02
# 12  0.357143  0.470588  2.150577e-02
# 13  0.452381  0.470588  3.024310e-03
# 14  0.452381  0.588235  1.482666e-04
# 15  0.476190  0.588235  5.078000e-05
# 16  0.476190  0.617647  4.007707e-05
# 17  0.500000  0.617647  2.788760e-05
# 18  0.500000  0.647059  9.085287e-06
# 19  0.571429  0.647059  4.999911e-07
# 20  0.571429  0.676471  1.278820e-07
# 21  0.619048  0.676471  6.003914e-08
# 22  0.619048  0.735294  9.206500e-11
# 23  0.642857  0.735294  3.379217e-11
# 24  0.642857  0.764706  2.767696e-11
# 25  0.738095  0.764706  1.071548e-12
# 26  0.738095  0.794118  1.045254e-12
# 27  0.761905  0.794118  7.579686e-13
# 28  0.761905  0.852941  2.297666e-15
# 29  0.880952  0.852941  2.595509e-27
# 30  0.880952  0.882353  1.332343e-27
# 31  0.952381  0.882353  7.650087e-31
# 32  0.952381  0.941176  6.115378e-37
# 33  1.000000  1.000000  0.000000e+00

# %%
from sklearn.metrics import roc_auc_score

auroc = roc_auc_score(
  dissim_df.is_similar[:num_batched_instances],
  pred_y_dis,
)

print('AUROC score:', auroc)
# Out:
# AUROC score: 0.6225490196078431

# %%
print('For probability:')
print(f'Mean: {pred_y_dis.mean()}, STD: {pred_y_dis.std()}')
print('For categorical:')
print(f'Mean: {(pred_y_dis > .5).mean()}, STD: {(pred_y_dis > .5).std()}')
# Out:
# For probability:
# Mean: 0.19318833947181702, STD: 0.2980053126811981
# For categorical:
# Mean: 0.2236842105263158, STD: 0.41671283216087146
